# %%
#run in GOOGLe COLAB,,it cant run in local m/c

# %%
#accessing data from TMDB(the movie database)
#https://api.themoviedb.org/3/movie/top_rated?api_key=0a12af225ce70ffc634065815d075120
#https://api.themoviedb.org/3/movie/top_rated-->this i taken from API refference and
#api_key=0a12af225ce70ffc634065815d075120  --> this is takne from clickon profile->settings->api->copy api and paste here

# %%
#but there are 451 total pages and each page has 20 movie info...and we want to access all movies so we have to modify url
#as campusX teached,,that one is old,,,now TMDB will provide code snippet so copy that and use it

# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYTEyYWYyMjVjZTcwZmZjNjM0MDY1ODE1ZDA3NTEyMCIsInN1YiI6IjY1NzdmMTQ2YTFkMzMyMDExYjRmY2Y1NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.48nodhQiWuOOkPeJ7D4xNb_3fOatgxx5vTlua8flzb8"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":20,"results":[{"adult":false,"backdrop_path":"/eGK2JJO1ZeoabWThHmC9IjUTmfP.jpg","genre_ids":[16,14,12],"id":615453,"original_language":"zh","original_title":"哪吒之魔童降世","overview":"The Primus extracts a Mixed Yuan Bead into a Spirit Seed and a Demon Pill. The Spirit Seed can be reincarnated as a human to help King Zhou establish a new dynasty, whereas the Demon Pill will create a devil threatening humanity. Ne Zha is the one who is destined to be the hero, but instead he becomes a devil incarnate, because the Spirit Seed and a Demon Pill are switched.","popularity":16.439,"poster_path":"/phM9bb6s9c60LA8qwsdk7U1N2cS.jpg","release_date":"2019-07-26","title":"Ne Zha","video":false,"vote_average":7.9,"vote_count":368},{"adult":false,"backdrop_path":"/4aFtD31RpP018y8XipTLrU8Y3pa.jpg","genre_ids":[12,10751,18],"id":458302,"original_language":"fr","original_title":"Rémi sans famille","overview":"At the age of 10 years, young Rémi is snatched from his adoptive mother and entrusted to t
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/eGK2JJO1ZeoabWThHmC9IjUTmfP.jpg',
#   'genre_ids': [16, 14, 12],
#   'id': 615453,
#   'original_language': 'zh',
#   'original_title': '哪吒之魔童降世',
#   'overview': 'The Primus extracts a Mixed Yuan Bead into a Spirit Seed and a Demon Pill. The Spirit Seed can be reincarnated as a human to help King Zhou establish a new dynasty, whereas the Demon Pill will create a devil threatening humanity. Ne Zha is the one who is destined to be the hero, but instead he becomes a devil incarnate, because the Spirit Seed and a Demon Pill are switched.',
#   'popularity': 16.439,
#   'poster_path': '/phM9bb6s9c60LA8qwsdk7U1N2cS.jpg',
#   'release_date': '2019-07-26',
#   'title': 'Ne Zha',
#   'video': False,
#   'vote_average': 7.9,
#   'vote_count': 368},
#  {'adult': False,
#   'backdrop_path': '/4aFtD31RpP018y8XipTLrU8Y3pa.jpg',
#   'genre_ids': [12, 10751, 18],
#   'id': 458302,
#   'original_language': 'fr',
#   'original_title': 'Rémi sans famille',
# ...

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','genre_ids','release_date','overview','popularity','vote_average','vote_count']]
temp_df
# Out:
#         id                                    title                genre_ids  \
# 0   615453                                   Ne Zha             [16, 14, 12]
# 1   458302                       Remi, Nobody's Boy          [12, 10751, 18]
# 2    10386                           The Iron Giant     [10751, 16, 878, 18]
# 3    10404                    Raise the Red Lantern                     [18]
# 4     8290   Don't Look Now... We're Being Shot At!              [35, 10752]
# 5   360814                                   Dangal      [18, 10751, 35, 28]
# 6     9323                       Ghost in the Shell            [28, 16, 878]
# 7       85                  Raiders of the Lost Ark                 [12, 28]
# 8    10242         What Ever Happened to Baby Jane?             [18, 27, 53]
# 9   785084                                The Whale                     [18]
# 10  501929           The Mitchells vs. the Machines             [16, 12, 35]
# ...

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,452):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=0a12af225ce70ffc634065815d075120&language=en-US&page={}".format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','genre_ids','release_date','overview','popularity','vote_average','vote_count']]
    df=df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-49-6a0f321296fd>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-49-6a0f321296fd>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-49-6a0f321296fd>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# <ipython-input-49-6a0f321296fd>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#          id                        title                 genre_ids  \
# 0       238                The Godfather                  [18, 80]
# 1       278     The Shawshank Redemption                  [18, 80]
# 2       240        The Godfather Part II                  [18, 80]
# 3       424             Schindler's List           [18, 36, 10752]
# 4     19404  Dilwale Dulhania Le Jayenge           [35, 18, 10749]
# ...     ...                          ...                       ...
# 9000  12142            Alone in the Dark              [28, 14, 27]
# 9001   5491            Battlefield Earth             [28, 12, 878]
# 9002  11059            House of the Dead              [27, 28, 53]
# 9003  14164         Dragonball Evolution     [28, 12, 14, 878, 53]
# 9004  40016   Birdemic: Shock and Terror  [53, 14, 10749, 27, 878]
#
#      release_date                                           overview  \
# 0      1972-03-14  Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
df.sort_values(by=['id'],inplace=True)

# %%
df
# Out:
#            id                        title        genre_ids release_date  \
# 2167        3          Shadows in Paradise  [18, 35, 10749]   1986-10-17
# 7774        5                   Four Rooms             [35]   1995-12-09
# 5001        6               Judgment Night     [28, 80, 53]   1993-10-15
# 122        11                    Star Wars    [12, 28, 878]   1977-05-25
# 543        12                 Finding Nemo      [16, 10751]   2003-05-30
# ...       ...                          ...              ...          ...
# 1220  1083862  Resident Evil: Death Island     [16, 28, 27]   2023-06-22
# 5336  1085218         Darkland: The Return         [53, 28]   2023-04-13
# 3511  1102776                          AKA             [28]   2023-04-28
# 4336  1140066                     Paradise        [878, 53]   2023-06-24
# 1202  1151534                      Nowhere         [53, 18]   2023-09-29
#
#                                                overview  popularity  \
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#            id                        title        genre_ids release_date  \
# 0           3          Shadows in Paradise  [18, 35, 10749]   1986-10-17
# 1           5                   Four Rooms             [35]   1995-12-09
# 2           6               Judgment Night     [28, 80, 53]   1993-10-15
# 3          11                    Star Wars    [12, 28, 878]   1977-05-25
# 4          12                 Finding Nemo      [16, 10751]   2003-05-30
# ...       ...                          ...              ...          ...
# 9000  1083862  Resident Evil: Death Island     [16, 28, 27]   2023-06-22
# 9001  1085218         Darkland: The Return         [53, 28]   2023-04-13
# 9002  1102776                          AKA             [28]   2023-04-28
# 9003  1140066                     Paradise        [878, 53]   2023-06-24
# 9004  1151534                      Nowhere         [53, 18]   2023-09-29
#
#                                                overview  popularity  \
# ...

# %%
#genres fetching from tmdb

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYTEyYWYyMjVjZTcwZmZjNjM0MDY1ODE1ZDA3NTEyMCIsInN1YiI6IjY1NzdmMTQ2YTFkMzMyMDExYjRmY2Y1NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.48nodhQiWuOOkPeJ7D4xNb_3fOatgxx5vTlua8flzb8"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
genres=response.json()['genres']
genres
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 37, 'name': 'Western'}]

# %%
list(df['genre_ids'])
# Out:
# [[18, 35, 10749],
#  [35],
#  [28, 80, 53],
#  [12, 28, 878],
#  [16, 10751],
#  [35, 18, 10749],
#  [18],
#  [9648, 18],
#  [18, 80],
#  [12, 14, 28, 53, 878],
#  [18, 878],
#  [18, 10749],
#  [12, 14, 28],
#  [28, 80],
#  [18, 10752],
#  [18, 10402, 10749],
#  [18, 10752],
#  [37],
#  [16, 35, 10751],
#  [878, 18, 10749],
#  [18, 53],
#  [12, 14, 28],
#  [18, 53, 80],
#  [878, 9648, 12],
#  [878, 53, 9648],
#  [18, 10749],
#  [18, 10402],
#  [80, 18, 28],
#  [35, 878],
#  [18, 10402, 10749],
#  [18],
#  [18, 35, 10402],
#  [18],
#  [12, 53, 878],
#  [35, 14, 878],
#  [18, 10749],
#  [9648, 53],
#  [878, 18, 53],
#  [18, 12, 28, 36],
#  [18, 10749],
#  [12, 16, 14],
#  [28, 80, 53],
#  [18, 53, 27],
#  [12, 28],
#  [12, 28],
#  [18, 10402, 10749],
#  [12, 28],
#  [28, 35, 80],
#  [80, 18, 9648],
#  [28, 53, 878, 12],
#  [28, 35, 80],
#  [878, 28, 12],
#  [28, 18, 12],
#  [35, 18],
#  [35, 80],
#  [80, 18, 28],
#  [80, 18],
#  [28, 18, 53],
#  [12, 35, 878],
#  [878, 28, 12, 53],
# ...

# %%
movie_genres_dict = {genre['id']: genre['name'] for genre in genres}
movie_genres_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
for i,g in enumerate(list(df['genre_ids'])):
    l=[]
    for e in g:
        if e in movie_genres_dict:
           l.append(movie_genres_dict[e])
    df['genre_ids'][i]=",".join(l)
df
# Out:
# <ipython-input-61-452defd36f2f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre_ids'][i]=",".join(l)
#            id                        title                         genre_ids  \
# 0           3          Shadows in Paradise              Drama,Comedy,Romance
# 1           5                   Four Rooms                            Comedy
# 2           6               Judgment Night             Action,Crime,Thriller
# 3          11                    Star Wars  Adventure,Action,Science Fiction
# 4          12                 Finding Nemo                  Animation,Family
# ...       ...                          ...                               ...
# 9000  1083862  Resident Evil: Death Island           Animation,Action,Horror
# ...
