# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('concentric.csv')

# %%
df.head()
# Out:
#           X         Y  class
# 0  0.700335 -0.247068    0.0
# 1 -3.950019  2.740080    1.0
# 2  0.150222 -2.157638    1.0
# 3 -1.672050 -0.941519    1.0
# 4  2.560483 -1.846577    1.0

# %%
plt.scatter(df['X'],df['Y'],c=df['class'])

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization

# %%
model = Sequential()

model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 2)                 6
#
#  dense_2 (Dense)             (None, 1)                 3
#
# ...
# Total params: 15 (60.00 Byte)
# Trainable params: 15 (60.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history1 = model.fit(X,y,epochs=200,validation_split=0.2)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 49ms/step - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4300
# Epoch 2/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6929 - accuracy: 0.5175 - val_loss: 0.6935 - val_accuracy: 0.4300
# Epoch 3/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6928 - accuracy: 0.5175 - val_loss: 0.6937 - val_accuracy: 0.4300
# Epoch 4/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6927 - accuracy: 0.5175 - val_loss: 0.6939 - val_accuracy: 0.4300
# Epoch 5/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6927 - accuracy: 0.5175 - val_loss: 0.6941 - val_accuracy: 0.4300
# Epoch 6/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6926 - accuracy: 0.5175 - val_loss: 0.6942 - val_accuracy: 0.4300
# Epoch 7/200
# ...

# %% [markdown]
# # BATCH NORMALIZATION

# %%
model = Sequential()

model.add(Dense(3,activation='relu',input_dim=2))
model.add(BatchNormalization())#match size mentioned during fit(),,,u learn while doing hyperparameter tuning
model.add(Dense(2,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 3)                 9
#
#  batch_normalization (Batch  (None, 3)                 12
#  Normalization)
#
#  dense_4 (Dense)             (None, 2)                 8
#
#  batch_normalization_1 (Bat  (None, 2)                 8
#  chNormalization)
#
#  dense_5 (Dense)             (None, 1)                 3
#
# ...
# Total params: 40 (160.00 Byte)
# Trainable params: 30 (120.00 Byte)
# Non-trainable params: 10 (40.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history2 = model.fit(X,y,epochs=200,validation_split=0.2)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 29ms/step - loss: 0.8144 - accuracy: 0.4575 - val_loss: 0.8176 - val_accuracy: 0.5300
# Epoch 2/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.8353 - accuracy: 0.4250 - val_loss: 0.8132 - val_accuracy: 0.5000
# Epoch 3/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.8180 - accuracy: 0.4400 - val_loss: 0.8058 - val_accuracy: 0.5000
# Epoch 4/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.8214 - accuracy: 0.4450 - val_loss: 0.7957 - val_accuracy: 0.4700
# Epoch 5/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7858 - accuracy: 0.4375 - val_loss: 0.7868 - val_accuracy: 0.4200
# Epoch 6/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7812 - accuracy: 0.4325 - val_loss: 0.7792 - val_accuracy: 0.3700
# Epoch 7/200
# ...

# %%
plt.plot(history1.history['val_accuracy'],color='black')#NN w/o batch normalization
plt.plot(history2.history['val_accuracy'],color='green')#NN with batch normalization
