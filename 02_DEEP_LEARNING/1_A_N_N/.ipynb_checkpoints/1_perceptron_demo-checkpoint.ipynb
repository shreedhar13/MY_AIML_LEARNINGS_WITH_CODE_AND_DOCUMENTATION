# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa    iq  placed
# 0  7.13  6.22       1
# 1  1.75  2.73       0
# 2  9.70  9.69       1
# 3  6.57  1.78       1
# 4  5.52  4.21       0

# %%
sns.scatterplot(x=df['cgpa'],y=df['iq'],hue=df['placed'])
#orange -->placed,,blue->not placed
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa    iq
# 0   7.13  6.22
# 1   1.75  2.73
# 2   9.70  9.69
# 3   6.57  1.78
# 4   5.52  4.21
# ..   ...   ...
# 95  5.26  2.58
# 96  2.53  6.15
# 97  6.00  6.58
# 98  6.02  2.77
# 99  7.81  7.24
#
# [100 rows x 2 columns]

# %%
X.values
# Out:
# array([[7.13, 6.22],
#        [1.75, 2.73],
#        [9.7 , 9.69],
#        [6.57, 1.78],
#        [5.52, 4.21],
#        [4.23, 8.45],
#        [1.85, 2.1 ],
#        [3.1 , 3.89],
#        [2.88, 9.39],
#        [6.03, 8.37],
#        [3.02, 1.95],
#        [1.06, 8.63],
#        [6.99, 7.14],
#        [9.56, 1.46],
#        [6.5 , 3.33],
#        [7.82, 5.68],
#        [1.37, 7.76],
#        [8.23, 9.96],
#        [1.93, 9.12],
#        [9.62, 8.13],
#        [2.42, 8.28],
#        [3.11, 9.53],
#        [2.33, 8.2 ],
#        [3.99, 7.86],
#        [2.88, 5.02],
#        [6.2 , 4.5 ],
#        [3.3 , 4.11],
#        [4.3 , 3.95],
#        [6.02, 6.7 ],
#        [2.98, 8.05],
#        [3.63, 2.23],
#        [9.46, 7.11],
#        [7.55, 6.97],
#        [1.34, 3.44],
#        [7.49, 8.36],
#        [7.53, 8.66],
#        [4.36, 5.38],
#        [8.72, 4.05],
#        [3.99, 1.51],
#        [5.19, 3.59],
#        [1.33, 8.71],
#        [4.52, 3.21],
#        [8.45, 2.21],
# ...

# %%
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    1
# 99    1
# Name: placed, Length: 100, dtype: int64

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
#training 
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 27.14, -12.23]])

# %%
p.intercept_
# Out:
# array([-134.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values,y.values,clf=p)#passing classifier as Perceptron object,,ie;calculated weights(coeff) and bias(intercept)
# Out:
# C:\Users\shree\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
#single neuron/perceptron/node bydefaultly(w/o any activation) works like linear_regression model
#and we give activation to acheive nonlinearity
