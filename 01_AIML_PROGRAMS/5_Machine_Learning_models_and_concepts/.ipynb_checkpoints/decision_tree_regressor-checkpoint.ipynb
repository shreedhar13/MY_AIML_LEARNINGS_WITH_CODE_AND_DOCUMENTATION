# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB')
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %%
X=df.drop('price',axis=1)#means drop price named column(ie;7120 rows of that column also deleted)#remaining are independent var
y=df['price']#dependent var
print('shape of x=',X.shape)
print('shape of y=',y.shape)
# Out:
# shape of x= (7120, 107)
# shape of y= (7120,)

# %% [markdown]
# # NOT NEED TO FEATURE SCALING,,bcz D.T.(C and R)  works very good on not scaled data also
# #but u can make feature scaling if u want

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)#note untill random_state=1,,how many times u execute this statement that many times it will generate same train and test dataset as it is there while executing 1st time
print('shape of X_train=',X_train.shape)
print('shape of y_train=',y_train.shape)
print('shape of X_test=',X_test.shape)
print('shape of y_test=',y_test.shape)
# Out:
# shape of X_train= (5696, 107)
# shape of y_train= (5696,)
# shape of X_test= (1424, 107)
# shape of y_test= (1424,)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#in D.T.C we use gini,entropy,info gain to split tree
#in D.T.R we use mse ,mae,friedman_mse..(mse-->squared_error,mae-->absolute_eroor)
regressor=DecisionTreeRegressor(criterion='squared_error')
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
regressor.score(X_test,y_test)#86% accuracy on unseen data
# Out:
# 0.8616586095170438

# %%
#NOTE_>python supports negative index also...
X_test.iloc[-1,:]#access last row with all column
# Out:
# bath                              2.000000
# balcony                           3.000000
# total_sqft_int                 1100.000000
# bhk                               2.000000
# price_per_sqft                 3181.818182
#                                   ...
# location_Hosur Road               0.000000
# location_Horamavu Banaswadi       0.000000
# location_Domlur                   0.000000
# location_Mahadevpura              0.000000
# location_Tumkur Road              0.000000
# Name: 250, Length: 107, dtype: float64

# %%
regressor.predict([X_test.iloc[-1,:]])#bcz .predict wants 2d data.v and this returns 1d
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([35.5])

# %%
y_test.iloc[-1]
# Out:
# 35.0

# %%
pred=regressor.predict(X_test)
pred
# Out:
# array([68.63, 32.9 , 85.05, ..., 30.  , 32.64, 35.5 ])

# %%
y_test
# Out:
# 4423     72.0
# 6520     34.0
# 6173     85.0
# 3485    155.0
# 4034     18.0
#         ...
# 2538     96.0
# 5514     54.0
# 4390     28.0
# 1490     32.0
# 250      35.0
# Name: price, Length: 1424, dtype: float64

# %%
#very closer

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(regressor,filled=True)
#as u see very complex tree,,,bcz we not specified parameters line max_depth ..etc so this model will split tree till it 
#all possible leaf node,,in that case our model can be overfit so,,hyparameter is truelry required
# Out:
# [Text(0.8774058836782186, 0.9791666666666666, 'x[2] <= 7650.0\nsquared_error = 14704.398\nsamples = 5696\nvalue = 97.173'),
#  Text(0.7566596956058437, 0.9375, 'x[2] <= 2176.5\nsquared_error = 6994.764\nsamples = 5684\nvalue = 93.356'),
#  Text(0.5600125604484611, 0.8958333333333334, 'x[4] <= 6182.782\nsquared_error = 1487.543\nsamples = 5072\nvalue = 72.946'),
#  Text(0.3376549824118251, 0.8541666666666666, 'x[2] <= 1325.5\nsquared_error = 412.141\nsamples = 3644\nvalue = 57.22'),
#  Text(0.1702791892513501, 0.8125, 'x[4] <= 4459.685\nsquared_error = 182.836\nsamples = 2663\nvalue = 48.703'),
#  Text(0.062493963865834036, 0.7708333333333334, 'x[2] <= 882.5\nsquared_error = 96.952\nsamples = 1222\nvalue = 39.621'),
#  Text(0.01936541188090421, 0.7291666666666666, 'x[2] <= 656.0\nsquared_error = 57.383\nsamples = 188\nvalue = 23.214'),
#  Text(0.010243257451452057, 0.6875, 'x[4] <= 3662.602\nsquared_error = 17.61\nsamples = 95\nvalue = 17.091'),
# ...
